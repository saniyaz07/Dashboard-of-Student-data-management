# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('nexus.csv')

# Display the first few rows
df.head()
# Out:
#   Student_ID Student_Age     Sex High_School_Type Scholarship Additional_Work  \
# 0   STUDENT1       19-22    Male            Other         50%             Yes
# 1   STUDENT2       19-22    Male            Other         NaN             Yes
# 2   STUDENT3       19-22    Male            State         50%              No
# 3   STUDENT4          18  Female          Private         50%             Yes
# 4   STUDENT5       19-22    Male          Private         50%              No
#
#   Sports_activity Transportation  Weekly_Study_Hours Attendance Reading Notes  \
# 0              No        Private                 0.0     Always     Yes   Yes
# 1              No        Private                 0.0     Always     Yes    No
# 2              No        Private                 2.0      Never      No    No
# 3              No            Bus                 2.0     Always      No   Yes
# 4              No            Bus                12.0     Always     NaN    No
#
#   Listening_in_Class Project_work Grade
# 0                 No           No    AA
# 1                Yes          Yes    AA
# 2                 No          Yes    AA
# 3                NaN           No    AA
# 4                Yes          Yes    AA

# %%
df_cleaned = df.dropna()

# Display the first few rows of the cleaned dataset
df_cleaned.head()
# Out:
#    Student_ID Student_Age     Sex High_School_Type Scholarship  \
# 0    STUDENT1       19-22    Male            Other         50%
# 2    STUDENT3       19-22    Male            State         50%
# 6    STUDENT7          18    Male            State         75%
# 12  STUDENT13          18  Female          Private         75%
# 17  STUDENT18       19-22    Male            State         50%
#
#    Additional_Work Sports_activity Transportation  Weekly_Study_Hours  \
# 0              Yes              No        Private            0.000000
# 2               No              No        Private            2.000000
# 6               No              No        Private            0.000000
# 12              No              No        Private            0.000000
# 17              No              No        Private          351.021644
#
#    Attendance Reading Notes Listening_in_Class Project_work Grade
# 0      Always     Yes   Yes                 No           No    AA
# 2       Never      No    No                 No          Yes    AA
# 6      Always      No   Yes                Yes          Yes    CC
# 12     Always     Yes    No                 No           No  Fail
# 17     Always     Yes    No                 No          Yes    BA

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# Fill NaN values in categorical columns with their mode
for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Verify that there are no NaN values left
print("Missing values after cleaning:\n", df.isnull().sum())

# Display the first few rows of the cleaned dataset
df.head()
# Out:
# Missing values after cleaning:
#  Student_ID            0
# Student_Age           0
# Sex                   0
# High_School_Type      0
# Scholarship           0
# Additional_Work       0
# Sports_activity       0
# Transportation        0
# Weekly_Study_Hours    0
# Attendance            0
# Reading               0
# Notes                 0
# Listening_in_Class    0
# Project_work          0
# Grade                 0
# dtype: int64
# <ipython-input-10-f19d240cb2cf>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)
#   Student_ID Student_Age     Sex High_School_Type Scholarship Additional_Work  \
# 0   STUDENT1       19-22    Male            Other         50%             Yes
# 1   STUDENT2       19-22    Male            Other         50%             Yes
# 2   STUDENT3       19-22    Male            State         50%              No
# 3   STUDENT4          18  Female          Private         50%             Yes
# 4   STUDENT5       19-22    Male          Private         50%              No
#
#   Sports_activity Transportation  Weekly_Study_Hours Attendance Reading Notes  \
# 0              No        Private                 0.0     Always     Yes   Yes
# 1              No        Private                 0.0     Always     Yes    No
# 2              No        Private                 2.0      Never      No    No
# 3              No            Bus                 2.0     Always      No   Yes
# 4              No            Bus                12.0     Always      No    No
#
#   Listening_in_Class Project_work Grade
# 0                 No           No    AA
# 1                Yes          Yes    AA
# 2                 No          Yes    AA
# 3                Yes           No    AA
# 4                Yes          Yes    AA

# %%
# Drop duplicate rows
df_cleaned = df.drop_duplicates()

# Display the first few rows of the cleaned dataset
df_cleaned.head()
# Out:
#   Student_ID Student_Age     Sex High_School_Type Scholarship Additional_Work  \
# 0   STUDENT1       19-22    Male            Other         50%             Yes
# 1   STUDENT2       19-22    Male            Other         50%             Yes
# 2   STUDENT3       19-22    Male            State         50%              No
# 3   STUDENT4          18  Female          Private         50%             Yes
# 4   STUDENT5       19-22    Male          Private         50%              No
#
#   Sports_activity Transportation  Weekly_Study_Hours Attendance Reading Notes  \
# 0              No        Private                 0.0     Always     Yes   Yes
# 1              No        Private                 0.0     Always     Yes    No
# 2              No        Private                 2.0      Never      No    No
# 3              No            Bus                 2.0     Always      No   Yes
# 4              No            Bus                12.0     Always      No    No
#
#   Listening_in_Class Project_work Grade
# 0                 No           No    AA
# 1                Yes          Yes    AA
# 2                 No          Yes    AA
# 3                Yes           No    AA
# 4                Yes          Yes    AA

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 145 entries, 0 to 144
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student_ID          145 non-null    object
#  1   Student_Age         145 non-null    object
#  2   Sex                 145 non-null    object
#  3   High_School_Type    145 non-null    object
#  4   Scholarship         145 non-null    object
#  5   Additional_Work     145 non-null    object
#  6   Sports_activity     145 non-null    object
#  7   Transportation      145 non-null    object
#  8   Weekly_Study_Hours  145 non-null    float64
#  9   Attendance          145 non-null    object
#  10  Reading             145 non-null    object
#  11  Notes               145 non-null    object
#  12  Listening_in_Class  145 non-null    object
#  13  Project_work        145 non-null    object
#  14  Grade               145 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 18.1+ KB
